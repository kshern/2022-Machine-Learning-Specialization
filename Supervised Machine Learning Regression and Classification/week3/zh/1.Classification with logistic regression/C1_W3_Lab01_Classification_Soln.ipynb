# %% [markdown]
# # Optional Lab: 使用逻辑回归分类
#
# 在这个实验中，您将对比回归和分类

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## 分类问题
#
# <img align="left" src="../../work/images/C1_W3_Classification.png"     style=" width:380px; padding: 10px; " > 分类问题的例子包括识别电子邮件是否为垃圾邮件，确定肿瘤是否为恶性或良性。特别地，这些都是二元分类的例子，即只有两种可能的结果。结果可以用“正”/“负”、“是”/“否”、“真”/“假”或“1”/“0”这样的一对方式来描述。
#
# 分类数据集的图通常使用符号来表示样本的结果。在下面的图中，“X”用于表示正值，而“O”表示负结果。

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0
fig,ax = plt.subplots(1,2,figsize=(8,3))
#plot 1, single variable
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=None, toolbar_visible=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 请注意上述图表中的内容
#
# -   在单变量图中，正结果既以红色的“X”显示，也以 y=1 显示。负结果为蓝色的“O”，位于 y=0 处。
#     -   请注意，在线性回归的情况下，y 不会限制为两个值，而可以是任何值。
# -   在双变量图中，y 轴不可用。正结果以红色的“X”表示，而负结果使用蓝色的“O”符号。
#     -   请注意，在具有多个变量的线性回归中，y 不会限制为两个值，并且类似的图表将是三维的。

# %% [markdown]
# ## 线性回归方法
#
# 在上一周，您应用了线性回归来构建预测模型。让我们尝试使用在讲座中描述的简单示例来使用该方法。该模型将根据肿瘤大小预测肿瘤是良性的还是恶性的。请尝试以下操作：
#
# -   单击“运行线性回归”以查找给定数据的最佳线性回归模型。 - 请注意，得到的线性模型与数据**不**匹配。
#     提高结果的一种选择是应用*阈值*。
# -   选中“切换 0.5 阈值”的框，以显示应用阈值后的预测结果。
#     -   这些预测看起来不错，预测结果与数据匹配。
# -   _重要提示_: 现在，在右侧远处的大肿瘤大小范围（接近 10）中添加更多“恶性”数据点，并重新运行线性回归。
#     -   现在，该模型预测了更大的肿瘤，但在 x=3 处的数据点被错误地预测！
# -   要清除/更新图表，请重新运行包含绘图命令的单元格。

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=None, toolbar_visible=False)

# %% [markdown]
# 上面的例子表明，线性模型不足以对分类数据建模。可以按照后面的实验室的描述扩展该模型。

# %% [markdown]
# ## Congratulations!
#
# In this lab you:
#
# -   explored categorical data sets and plotting
# -   determined that linear regression was insufficient for logistic regression.
